# %%
class DaGiac:
    def __init__(self):
        pass  

    def chu_vi(self):
        return 0

    def dien_tich(self):
        return 0

    def nhap_thong_tin(self):
        pass
class HinhBinhHanh(DaGiac):
    def __init__(self):
        super().__init__()
        self.day = 0
        self.canh_ben = 0
        self.chieu_cao = 0

    def nhap_thong_tin(self):
        self.day = float(input("Nhap do dai day: "))
        self.canh_ben = float(input("Nhap do dai canh ben: "))
        self.chieu_cao = float(input("Nhap chieu cao tu day: "))

    def chu_vi(self):
        return 2 * (self.day + self.canh_ben)

    def dien_tich(self):
        return self.day * self.chieu_cao
class HinhChuNhat(HinhBinhHanh):
    def __init__(self):
        super().__init__()

    def nhap_thong_tin(self):
        self.day = float(input("Nhap chieu dai: "))
        self.canh_ben = float(input("Nhap chieu rong: "))
        self.chieu_cao = self.canh_ben  # Do hinh chu nhat co goc vuong

    def chu_vi(self):
        return 2 * (self.day + self.canh_ben)

    def dien_tich(self):
        return self.day * self.canh_ben
class HinhVuong(HinhChuNhat):
    def __init__(self):
        super().__init__()

    def nhap_thong_tin(self):
        canh = float(input("Nhap do dai canh hinh vuong: "))
        self.day = canh
        self.canh_ben = canh
        self.chieu_cao = canh

    def chu_vi(self):
        return 4 * self.day

    def dien_tich(self):
        return self.day * self.day
def main():
    print("=== HINH BINH HANH ===")
    hbh = HinhBinhHanh()
    hbh.nhap_thong_tin()
    print(f"Chu vi: {hbh.chu_vi()}")
    print(f"Dien tich: {hbh.dien_tich()}")

    print("\n=== HINH CHU NHAT ===")
    hcn = HinhChuNhat()
    hcn.nhap_thong_tin()
    print(f"Chu vi: {hcn.chu_vi()}")
    print(f"Dien tich: {hcn.dien_tich()}")

    print("\n=== HINH VUONG ===")
    hv = HinhVuong()
    hv.nhap_thong_tin()
    print(f"Chu vi: {hv.chu_vi()}")
    print(f"Dien tich: {hv.dien_tich()}")
main()
